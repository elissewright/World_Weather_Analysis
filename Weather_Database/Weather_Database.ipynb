# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = list()

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 762

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_latitude = city_weather["coord"]["lat"]
        city_longitude = city_weather["coord"]["lon"]
        country_name = city_weather["sys"]["country"]
        city_max_temperature = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_cloudiness = city_weather["clouds"]["all"]
        city_wind_speed = city_weather["wind"]["speed"]
        weather_description = city_weather['weather'][0]['description']
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Country": country_name,
                          "Lat": city_latitude,
                          "Lng": city_longitude,
                          "Max Temp": city_max_temperature,
                          "Humidity": city_humidity,
                          "Cloudiness": city_cloudiness,
                          "Wind Speed": city_wind_speed,
                          "Current Description": weather_description })
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | asau
# Processing Record 2 of Set 1 | tuktoyaktuk
# Processing Record 3 of Set 1 | qaanaaq
# Processing Record 4 of Set 1 | rawson
# Processing Record 5 of Set 1 | batemans bay
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | waingapu
# Processing Record 8 of Set 1 | kapaa
# Processing Record 9 of Set 1 | ruwi
# Processing Record 10 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 1 | albac
# Processing Record 12 of Set 1 | saldanha
# Processing Record 13 of Set 1 | clyde river
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | slave lake
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | naze
# Processing Record 18 of Set 1 | samarai
# Processing Record 19 of Set 1 | raudeberg
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | yanam
# Processing Record 22 of Set 1 | chuy
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | broken hill
# Processing Record 25 of Set 1 | amahai
# Processing Record 26 of Set 1 | ambunti
# Processing Record 27 of Set 1 | pandan
# Processing Record 28 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 1 | boca do acre
# Processing Record 30 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | joensuu
# Processing Record 35 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 36 of Set 1 | penhold
# Processing Record 37 of Set 1 | mizdah
# Processing Record 38 of Set 1 | bathsheba
# Processing Record 39 of Set 1 | saint-augustin
# Processing Record 40 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 41 of Set 1 | auchel
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 1 | upernavik
# Processing Record 45 of Set 1 | east london
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | new norfolk
# Processing Record 48 of Set 1 | herat
# Processing Record 49 of Set 1 | leningradskiy
# Processing Record 50 of Set 1 | cabo san lucas
# Processing Record 1 of Set 2 | sri aman
# Processing Record 2 of Set 2 | castro
# Processing Record 3 of Set 2 | faanui
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | chokurdakh
# Processing Record 6 of Set 2 | antofagasta
# Processing Record 7 of Set 2 | tuatapere
# Processing Record 8 of Set 2 | galveston
# Processing Record 9 of Set 2 | plettenberg bay
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 2 | raton
# Processing Record 13 of Set 2 | axim
# Processing Record 14 of Set 2 | balakliya
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | butaritari
# Processing Record 17 of Set 2 | fairbanks
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | vila franca do campo
# Processing Record 20 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 2 | fortuna
# Processing Record 22 of Set 2 | olafsvik
# Processing Record 23 of Set 2 | silyanah
# City not found. Skipping...
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | ingelheim
# City not found. Skipping...
# Processing Record 26 of Set 2 | zonguldak
# Processing Record 27 of Set 2 | ketchikan
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | tiksi
# Processing Record 30 of Set 2 | norman wells
# Processing Record 31 of Set 2 | kachikau
# City not found. Skipping...
# Processing Record 32 of Set 2 | hermanus
# Processing Record 33 of Set 2 | puerto del rosario
# Processing Record 34 of Set 2 | atuona
# Processing Record 35 of Set 2 | goldsboro
# Processing Record 36 of Set 2 | mar del plata
# Processing Record 37 of Set 2 | maracas
# Processing Record 38 of Set 2 | tres picos
# Processing Record 39 of Set 2 | rock sound
# Processing Record 40 of Set 2 | torbay
# Processing Record 41 of Set 2 | bayonet point
# Processing Record 42 of Set 2 | sanmenxia
# Processing Record 43 of Set 2 | kiruna
# Processing Record 44 of Set 2 | arrifes
# Processing Record 45 of Set 2 | georgetown
# Processing Record 46 of Set 2 | florian
# Processing Record 47 of Set 2 | ratnagiri
# Processing Record 48 of Set 2 | geresk
# City not found. Skipping...
# Processing Record 49 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 2 | saint-philippe
# Processing Record 1 of Set 3 | nome
# Processing Record 2 of Set 3 | pisco
# Processing Record 3 of Set 3 | vardo
# Processing Record 4 of Set 3 | sarangani
# Processing Record 5 of Set 3 | lethem
# Processing Record 6 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 3 | chapais
# Processing Record 8 of Set 3 | viransehir
# Processing Record 9 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 3 | sapa
# Processing Record 11 of Set 3 | barcelos
# Processing Record 12 of Set 3 | guicheng
# City not found. Skipping...
# Processing Record 13 of Set 3 | hilo
# Processing Record 14 of Set 3 | la sarre
# Processing Record 15 of Set 3 | pacific grove
# Processing Record 16 of Set 3 | aksu
# Processing Record 17 of Set 3 | tura
# Processing Record 18 of Set 3 | yellowknife
# Processing Record 19 of Set 3 | sinnamary
# Processing Record 20 of Set 3 | lagoa santa
# Processing Record 21 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 3 | blagoyevo
# Processing Record 23 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 25 of Set 3 | san cristobal
# Processing Record 26 of Set 3 | manaure
# Processing Record 27 of Set 3 | yeppoon
# Processing Record 28 of Set 3 | uvira
# Processing Record 29 of Set 3 | maniitsoq
# Processing Record 30 of Set 3 | maningrida
# Processing Record 31 of Set 3 | kondinskoye
# Processing Record 32 of Set 3 | carnarvon
# Processing Record 33 of Set 3 | nanortalik
# Processing Record 34 of Set 3 | kavieng
# Processing Record 35 of Set 3 | liverpool
# Processing Record 36 of Set 3 | lebu
# Processing Record 37 of Set 3 | jamestown
# Processing Record 38 of Set 3 | batsfjord
# Processing Record 39 of Set 3 | caravelas
# Processing Record 40 of Set 3 | thompson
# Processing Record 41 of Set 3 | parfenyevo
# Processing Record 42 of Set 3 | luderitz
# Processing Record 43 of Set 3 | bluff
# Processing Record 44 of Set 3 | oltu
# Processing Record 45 of Set 3 | kodiak
# Processing Record 46 of Set 3 | bredasdorp
# Processing Record 47 of Set 3 | chumikan
# Processing Record 48 of Set 3 | manono
# Processing Record 49 of Set 3 | brae
# Processing Record 50 of Set 3 | belmonte
# Processing Record 1 of Set 4 | longyearbyen
# Processing Record 2 of Set 4 | ribeira grande
# Processing Record 3 of Set 4 | bambous virieux
# Processing Record 4 of Set 4 | hualmay
# Processing Record 5 of Set 4 | puerto ayora
# Processing Record 6 of Set 4 | marsa matruh
# Processing Record 7 of Set 4 | dikson
# Processing Record 8 of Set 4 | abeche
# Processing Record 9 of Set 4 | kashi
# Processing Record 10 of Set 4 | erzin
# Processing Record 11 of Set 4 | coromandel
# Processing Record 12 of Set 4 | sodertalje
# City not found. Skipping...
# Processing Record 13 of Set 4 | labuhan
# Processing Record 14 of Set 4 | ambovombe
# Processing Record 15 of Set 4 | kirakira
# Processing Record 16 of Set 4 | morgantown
# Processing Record 17 of Set 4 | quatre cocos
# Processing Record 18 of Set 4 | merauke
# Processing Record 19 of Set 4 | romny
# Processing Record 20 of Set 4 | omboue
# Processing Record 21 of Set 4 | olinda
# Processing Record 22 of Set 4 | touros
# Processing Record 23 of Set 4 | nikolskoye
# Processing Record 24 of Set 4 | esperance
# Processing Record 25 of Set 4 | geraldton
# Processing Record 26 of Set 4 | guerrero negro
# Processing Record 27 of Set 4 | ambulu
# Processing Record 28 of Set 4 | meulaboh
# Processing Record 29 of Set 4 | hasaki
# Processing Record 30 of Set 4 | mount gambier
# Processing Record 31 of Set 4 | beringovskiy
# Processing Record 32 of Set 4 | avera
# Processing Record 33 of Set 4 | vallenar
# Processing Record 34 of Set 4 | vilhena
# Processing Record 35 of Set 4 | chany
# Processing Record 36 of Set 4 | new london
# Processing Record 37 of Set 4 | campo de criptana
# Processing Record 38 of Set 4 | lata
# Processing Record 39 of Set 4 | wenling
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | sioux lookout
# Processing Record 42 of Set 4 | waipawa
# Processing Record 43 of Set 4 | verkh-chebula
# Processing Record 44 of Set 4 | alice springs
# Processing Record 45 of Set 4 | pine bluff
# Processing Record 46 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 4 | koraput
# Processing Record 48 of Set 4 | salalah
# Processing Record 49 of Set 4 | vestmannaeyjar
# Processing Record 50 of Set 4 | narsaq
# Processing Record 1 of Set 5 | mountain home
# Processing Record 2 of Set 5 | grand gaube
# Processing Record 3 of Set 5 | semnan
# Processing Record 4 of Set 5 | constitucion
# Processing Record 5 of Set 5 | cockburn town
# Processing Record 6 of Set 5 | banjarmasin
# Processing Record 7 of Set 5 | kazachinskoye
# Processing Record 8 of Set 5 | quelimane
# Processing Record 9 of Set 5 | ndioum
# Processing Record 10 of Set 5 | sitka
# Processing Record 11 of Set 5 | qaqortoq
# Processing Record 12 of Set 5 | dengzhou
# Processing Record 13 of Set 5 | baykit
# Processing Record 14 of Set 5 | shakhtinsk
# Processing Record 15 of Set 5 | chippewa falls
# Processing Record 16 of Set 5 | kaitangata
# Processing Record 17 of Set 5 | san patricio
# Processing Record 18 of Set 5 | khatanga
# Processing Record 19 of Set 5 | worland
# Processing Record 20 of Set 5 | grindavik
# Processing Record 21 of Set 5 | muli
# Processing Record 22 of Set 5 | tazovskiy
# Processing Record 23 of Set 5 | gamba
# Processing Record 24 of Set 5 | swellendam
# Processing Record 25 of Set 5 | terekli-mekteb
# Processing Record 26 of Set 5 | severo-kurilsk
# Processing Record 27 of Set 5 | dombarovskiy
# Processing Record 28 of Set 5 | hambantota
# Processing Record 29 of Set 5 | polewali
# Processing Record 30 of Set 5 | victoria
# Processing Record 31 of Set 5 | tabory
# Processing Record 32 of Set 5 | lorengau
# Processing Record 33 of Set 5 | shimoda
# Processing Record 34 of Set 5 | enshi
# Processing Record 35 of Set 5 | ahuimanu
# Processing Record 36 of Set 5 | airai
# Processing Record 37 of Set 5 | codrington
# Processing Record 38 of Set 5 | shizuishan
# Processing Record 39 of Set 5 | barrow
# Processing Record 40 of Set 5 | manzanillo
# Processing Record 41 of Set 5 | sao joao da barra
# Processing Record 42 of Set 5 | saskylakh
# Processing Record 43 of Set 5 | coihaique
# Processing Record 44 of Set 5 | wilson
# Processing Record 45 of Set 5 | los algarrobos
# Processing Record 46 of Set 5 | buta
# Processing Record 47 of Set 5 | rocha
# Processing Record 48 of Set 5 | cidreira
# Processing Record 49 of Set 5 | myaundzha
# Processing Record 50 of Set 5 | husavik
# Processing Record 1 of Set 6 | shache
# Processing Record 2 of Set 6 | port alfred
# Processing Record 3 of Set 6 | ancud
# Processing Record 4 of Set 6 | vila
# Processing Record 5 of Set 6 | suaza
# Processing Record 6 of Set 6 | praia
# Processing Record 7 of Set 6 | hervey bay
# Processing Record 8 of Set 6 | toora-khem
# Processing Record 9 of Set 6 | lakselv
# Processing Record 10 of Set 6 | hanna
# Processing Record 11 of Set 6 | drama
# Processing Record 12 of Set 6 | thano bula khan
# City not found. Skipping...
# Processing Record 13 of Set 6 | farafangana
# Processing Record 14 of Set 6 | port blair
# Processing Record 15 of Set 6 | karoi
# Processing Record 16 of Set 6 | port elizabeth
# Processing Record 17 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 6 | balkanabat
# Processing Record 19 of Set 6 | pangoa
# Processing Record 20 of Set 6 | ibra
# Processing Record 21 of Set 6 | padang
# Processing Record 22 of Set 6 | hargeysa
# Processing Record 23 of Set 6 | verkhneyarkeyevo
# Processing Record 24 of Set 6 | hirado
# Processing Record 25 of Set 6 | prince rupert
# Processing Record 26 of Set 6 | zabid
# Processing Record 27 of Set 6 | kushima
# Processing Record 28 of Set 6 | avarua
# Processing Record 29 of Set 6 | tahoua
# Processing Record 30 of Set 6 | fallon
# Processing Record 31 of Set 6 | tevriz
# Processing Record 32 of Set 6 | mulhouse
# Processing Record 33 of Set 6 | singkang
# Processing Record 34 of Set 6 | maldonado
# Processing Record 35 of Set 6 | los llanos de aridane
# Processing Record 36 of Set 6 | great yarmouth
# Processing Record 37 of Set 6 | cervo
# Processing Record 38 of Set 6 | nishihara
# Processing Record 39 of Set 6 | tucurui
# Processing Record 40 of Set 6 | sola
# Processing Record 41 of Set 6 | flinders
# Processing Record 42 of Set 6 | zhigansk
# Processing Record 43 of Set 6 | churapcha
# Processing Record 44 of Set 6 | bandarbeyla
# Processing Record 45 of Set 6 | faya
# Processing Record 46 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 47 of Set 6 | kommunisticheskiy
# Processing Record 48 of Set 6 | san andres
# Processing Record 49 of Set 6 | port hardy
# Processing Record 50 of Set 6 | panjwin
# City not found. Skipping...
# Processing Record 1 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 7 | barsovo
# Processing Record 3 of Set 7 | asyut
# Processing Record 4 of Set 7 | ponta do sol
# Processing Record 5 of Set 7 | shelburne
# Processing Record 6 of Set 7 | berlevag
# Processing Record 7 of Set 7 | port lincoln
# Processing Record 8 of Set 7 | dingle
# Processing Record 9 of Set 7 | bafq
# Processing Record 10 of Set 7 | tigil
# Processing Record 11 of Set 7 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 7 | clifton
# Processing Record 13 of Set 7 | xiongyue
# Processing Record 14 of Set 7 | atka
# City not found. Skipping...
# Processing Record 15 of Set 7 | marsh harbour
# Processing Record 16 of Set 7 | apple valley
# Processing Record 17 of Set 7 | goderich
# Processing Record 18 of Set 7 | jibuti
# Processing Record 19 of Set 7 | rossland
# Processing Record 20 of Set 7 | cururupu
# Processing Record 21 of Set 7 | koungou
# Processing Record 22 of Set 7 | bud
# Processing Record 23 of Set 7 | santa cruz
# Processing Record 24 of Set 7 | xuddur
# Processing Record 25 of Set 7 | kruisfontein
# Processing Record 26 of Set 7 | baiyin
# Processing Record 27 of Set 7 | namibe
# Processing Record 28 of Set 7 | honiara
# Processing Record 29 of Set 7 | souillac
# Processing Record 30 of Set 7 | namatanai
# Processing Record 31 of Set 7 | tabou
# Processing Record 32 of Set 7 | koumac
# Processing Record 33 of Set 7 | vaitape
# Processing Record 34 of Set 7 | tarabuco
# Processing Record 35 of Set 7 | ostrovnoy
# Processing Record 36 of Set 7 | san carlos de bariloche
# Processing Record 37 of Set 7 | galle
# Processing Record 38 of Set 7 | bengkulu
# Processing Record 39 of Set 7 | okhotsk
# Processing Record 40 of Set 7 | oravita
# Processing Record 41 of Set 7 | aklavik
# Processing Record 42 of Set 7 | provideniya
# Processing Record 43 of Set 7 | kibala
# Processing Record 44 of Set 7 | tanshui
# City not found. Skipping...
# Processing Record 45 of Set 7 | sao filipe
# Processing Record 46 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 7 | gat
# Processing Record 48 of Set 7 | katsuura
# Processing Record 49 of Set 7 | sabang
# Processing Record 50 of Set 7 | amurzet
# Processing Record 1 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 2 of Set 8 | helong
# Processing Record 3 of Set 8 | russell
# Processing Record 4 of Set 8 | makakilo city
# Processing Record 5 of Set 8 | areosa
# Processing Record 6 of Set 8 | araouane
# Processing Record 7 of Set 8 | nazilli
# Processing Record 8 of Set 8 | port-cartier
# Processing Record 9 of Set 8 | darnah
# Processing Record 10 of Set 8 | coquimbo
# Processing Record 11 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 12 of Set 8 | zaraza
# Processing Record 13 of Set 8 | durant
# Processing Record 14 of Set 8 | kahului
# Processing Record 15 of Set 8 | songjianghe
# Processing Record 16 of Set 8 | yulara
# Processing Record 17 of Set 8 | farmington
# Processing Record 18 of Set 8 | thinadhoo
# Processing Record 19 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 20 of Set 8 | camocim
# Processing Record 21 of Set 8 | carballo
# Processing Record 22 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 23 of Set 8 | bairiki
# Processing Record 24 of Set 8 | north bend
# Processing Record 25 of Set 8 | vlasikha
# Processing Record 26 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 8 | hay river
# Processing Record 28 of Set 8 | stromness
# Processing Record 29 of Set 8 | saint george
# Processing Record 30 of Set 8 | nicoya
# Processing Record 31 of Set 8 | taltal
# Processing Record 32 of Set 8 | alacranes
# Processing Record 33 of Set 8 | tual
# Processing Record 34 of Set 8 | abu dhabi
# Processing Record 35 of Set 8 | kyaka
# Processing Record 36 of Set 8 | karratha
# Processing Record 37 of Set 8 | gaoua
# Processing Record 38 of Set 8 | lagoa
# Processing Record 39 of Set 8 | katangli
# Processing Record 40 of Set 8 | huazolotitlan
# City not found. Skipping...
# Processing Record 41 of Set 8 | atlantic city
# Processing Record 42 of Set 8 | noumea
# Processing Record 43 of Set 8 | qasigiannguit
# Processing Record 44 of Set 8 | vila velha
# Processing Record 45 of Set 8 | puerto escondido
# Processing Record 46 of Set 8 | udachnyy
# Processing Record 47 of Set 8 | camacha
# Processing Record 48 of Set 8 | panji
# Processing Record 49 of Set 8 | iqaluit
# Processing Record 50 of Set 8 | begoro
# Processing Record 1 of Set 9 | hnaberd
# Processing Record 2 of Set 9 | nuristan
# Processing Record 3 of Set 9 | ayolas
# Processing Record 4 of Set 9 | gwadar
# Processing Record 5 of Set 9 | saint-pierre
# Processing Record 6 of Set 9 | monrovia
# Processing Record 7 of Set 9 | hagere selam
# Processing Record 8 of Set 9 | bonavista
# Processing Record 9 of Set 9 | kalabo
# Processing Record 10 of Set 9 | nelspruit
# Processing Record 11 of Set 9 | ust-nera
# Processing Record 12 of Set 9 | matamoros
# Processing Record 13 of Set 9 | itarema
# Processing Record 14 of Set 9 | muskegon
# Processing Record 15 of Set 9 | teknaf
# Processing Record 16 of Set 9 | khandyga
# Processing Record 17 of Set 9 | tyubuk
# Processing Record 18 of Set 9 | paamiut
# Processing Record 19 of Set 9 | tessalit
# Processing Record 20 of Set 9 | zhezkazgan
# Processing Record 21 of Set 9 | morondava
# Processing Record 22 of Set 9 | matara
# Processing Record 23 of Set 9 | jian
# Processing Record 24 of Set 9 | mareeba
# Processing Record 25 of Set 9 | santa quiteria
# Processing Record 26 of Set 9 | mendeleyevo
# Processing Record 27 of Set 9 | roebourne
# Processing Record 28 of Set 9 | tezu
# Processing Record 29 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 30 of Set 9 | dali
# Processing Record 31 of Set 9 | yaroslavl
# Processing Record 32 of Set 9 | sawtell
# Processing Record 33 of Set 9 | tamandare
# Processing Record 34 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 9 | rio gallegos
# Processing Record 36 of Set 9 | oppdal
# Processing Record 37 of Set 9 | neyshabur
# Processing Record 38 of Set 9 | nuuk
# Processing Record 39 of Set 9 | qui nhon
# Processing Record 40 of Set 9 | strezhevoy
# Processing Record 41 of Set 9 | huarmey
# Processing Record 42 of Set 9 | vila do maio
# Processing Record 43 of Set 9 | yar-sale
# Processing Record 44 of Set 9 | trinidad
# Processing Record 45 of Set 9 | blackwater
# Processing Record 46 of Set 9 | spring hill
# Processing Record 47 of Set 9 | ilulissat
# Processing Record 48 of Set 9 | bahir dar
# Processing Record 49 of Set 9 | acarau
# Processing Record 50 of Set 9 | turbat
# Processing Record 1 of Set 10 | rio grande
# Processing Record 2 of Set 10 | matai
# Processing Record 3 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 4 of Set 10 | tommot
# Processing Record 5 of Set 10 | mubende
# Processing Record 6 of Set 10 | crossville
# Processing Record 7 of Set 10 | salinas
# Processing Record 8 of Set 10 | yaan
# Processing Record 9 of Set 10 | coari
# Processing Record 10 of Set 10 | nampula
# Processing Record 11 of Set 10 | nelson bay
# Processing Record 12 of Set 10 | borba
# Processing Record 13 of Set 10 | vagur
# Processing Record 14 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 15 of Set 10 | san ignacio
# Processing Record 16 of Set 10 | jalu
# Processing Record 17 of Set 10 | agua branca
# Processing Record 18 of Set 10 | donnacona
# Processing Record 19 of Set 10 | joshimath
# Processing Record 20 of Set 10 | rantoul
# Processing Record 21 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 22 of Set 10 | preobrazheniye
# Processing Record 23 of Set 10 | ovalle
# Processing Record 24 of Set 10 | erenhot
# Processing Record 25 of Set 10 | winnemucca
# Processing Record 26 of Set 10 | parlakimidi
# Processing Record 27 of Set 10 | chincha alta
# Processing Record 28 of Set 10 | harper
# Processing Record 29 of Set 10 | stornoway
# Processing Record 30 of Set 10 | bozuyuk
# Processing Record 31 of Set 10 | nueve de julio
# Processing Record 32 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 33 of Set 10 | mazagao
# Processing Record 34 of Set 10 | hami
# Processing Record 35 of Set 10 | nyrob
# Processing Record 36 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 10 | ampanihy
# Processing Record 38 of Set 10 | novyy svit
# Processing Record 39 of Set 10 | broome
# Processing Record 40 of Set 10 | chengmai
# City not found. Skipping...
# Processing Record 41 of Set 10 | klaksvik
# Processing Record 42 of Set 10 | tabuk
# Processing Record 43 of Set 10 | magadan
# Processing Record 44 of Set 10 | amapa
# Processing Record 45 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 10 | caucaia
# Processing Record 47 of Set 10 | lubao
# Processing Record 48 of Set 10 | egvekinot
# Processing Record 49 of Set 10 | abbeville
# Processing Record 50 of Set 10 | angoche
# Processing Record 1 of Set 11 | qiongshan
# Processing Record 2 of Set 11 | najran
# Processing Record 3 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 11 | pevek
# Processing Record 5 of Set 11 | izhma
# Processing Record 6 of Set 11 | collie
# Processing Record 7 of Set 11 | mansa
# Processing Record 8 of Set 11 | iracoubo
# Processing Record 9 of Set 11 | auki
# Processing Record 10 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 11 of Set 11 | middelburg
# Processing Record 12 of Set 11 | dzaoudzi
# Processing Record 13 of Set 11 | lodja
# Processing Record 14 of Set 11 | moose factory
# Processing Record 15 of Set 11 | ciudad bolivar
# Processing Record 16 of Set 11 | morant bay
# Processing Record 17 of Set 11 | kuznechnoye
# Processing Record 18 of Set 11 | alofi
# Processing Record 19 of Set 11 | wilmington
# Processing Record 20 of Set 11 | innisfail
# Processing Record 21 of Set 11 | tangjiazhuang
# Processing Record 22 of Set 11 | hofn
# Processing Record 23 of Set 11 | awjilah
# Processing Record 24 of Set 11 | aranos
# Processing Record 25 of Set 11 | adrar
# Processing Record 26 of Set 11 | dorverden
# Processing Record 27 of Set 11 | lasa
# Processing Record 28 of Set 11 | nador
# Processing Record 29 of Set 11 | braganca
# Processing Record 30 of Set 11 | mount isa
# Processing Record 31 of Set 11 | hamilton
# Processing Record 32 of Set 11 | san lawrenz
# Processing Record 33 of Set 11 | asfi
# Processing Record 34 of Set 11 | pontianak
# Processing Record 35 of Set 11 | saint-joseph
# Processing Record 36 of Set 11 | solnechnyy
# Processing Record 37 of Set 11 | college
# Processing Record 38 of Set 11 | tilichiki
# Processing Record 39 of Set 11 | aboso
# Processing Record 40 of Set 11 | comodoro rivadavia
# Processing Record 41 of Set 11 | kieta
# Processing Record 42 of Set 11 | pinos puente
# Processing Record 43 of Set 11 | marzuq
# Processing Record 44 of Set 11 | socorro
# Processing Record 45 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 46 of Set 11 | nova aurora
# Processing Record 47 of Set 11 | kavaratti
# Processing Record 48 of Set 11 | kupang
# Processing Record 49 of Set 11 | te anau
# Processing Record 50 of Set 11 | bam
# Processing Record 1 of Set 12 | kalmar
# Processing Record 2 of Set 12 | nizhnyaya tavda
# Processing Record 3 of Set 12 | methven
# Processing Record 4 of Set 12 | mnogovershinnyy
# Processing Record 5 of Set 12 | cottonwood
# Processing Record 6 of Set 12 | hue
# Processing Record 7 of Set 12 | viedma
# Processing Record 8 of Set 12 | palmas bellas
# Processing Record 9 of Set 12 | coelho neto
# Processing Record 10 of Set 12 | peniche
# Processing Record 11 of Set 12 | virginia beach
# Processing Record 12 of Set 12 | cacoal
# Processing Record 13 of Set 12 | srednekolymsk
# Processing Record 14 of Set 12 | ishigaki
# Processing Record 15 of Set 12 | ati
# Processing Record 16 of Set 12 | punta cardon
# Processing Record 17 of Set 12 | cayenne
# Processing Record 18 of Set 12 | rincon
# Processing Record 19 of Set 12 | dakar
# Processing Record 20 of Set 12 | bageshwar
# Processing Record 21 of Set 12 | cerveteri
# Processing Record 22 of Set 12 | kalmunai
# Processing Record 23 of Set 12 | taitung
# Processing Record 24 of Set 12 | carman
# Processing Record 25 of Set 12 | chastoozerye
# City not found. Skipping...
# Processing Record 26 of Set 12 | mae sai
# Processing Record 27 of Set 12 | port hedland
# Processing Record 28 of Set 12 | kropotkin
# Processing Record 29 of Set 12 | skibbereen
# Processing Record 30 of Set 12 | tiznit
# Processing Record 31 of Set 12 | ararangua
# Processing Record 32 of Set 12 | la asuncion
# Processing Record 33 of Set 12 | miles city
# Processing Record 34 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 12 | zomergem
# Processing Record 36 of Set 12 | ofaqim
# Processing Record 37 of Set 12 | mackay
# Processing Record 38 of Set 12 | dera din panah
# City not found. Skipping...
# Processing Record 39 of Set 12 | henties bay
# Processing Record 40 of Set 12 | rakovnik
# Processing Record 41 of Set 12 | akcaabat
# Processing Record 42 of Set 12 | ouadda
# Processing Record 43 of Set 12 | bogorodskoye
# Processing Record 44 of Set 12 | puerto leguizamo
# Processing Record 45 of Set 12 | gizo
# Processing Record 46 of Set 12 | gurgan
# City not found. Skipping...
# Processing Record 47 of Set 12 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 12 | yumen
# Processing Record 49 of Set 12 | muros
# Processing Record 50 of Set 12 | amga
# Processing Record 1 of Set 13 | jumla
# Processing Record 2 of Set 13 | kloulklubed
# Processing Record 3 of Set 13 | el wasta
# City not found. Skipping...
# Processing Record 4 of Set 13 | kang
# Processing Record 5 of Set 13 | nemuro
# Processing Record 6 of Set 13 | yerbogachen
# Processing Record 7 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 13 | kelme
# Processing Record 9 of Set 13 | talnakh
# Processing Record 10 of Set 13 | bongouanou
# Processing Record 11 of Set 13 | terrace bay
# Processing Record 12 of Set 13 | orange cove
# Processing Record 13 of Set 13 | nabire
# Processing Record 14 of Set 13 | beira
# Processing Record 15 of Set 13 | eyl
# Processing Record 16 of Set 13 | athabasca
# Processing Record 17 of Set 13 | bodden town
# Processing Record 18 of Set 13 | kasane
# Processing Record 19 of Set 13 | zhaotong
# Processing Record 20 of Set 13 | karakol
# Processing Record 21 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 13 | pangnirtung
# Processing Record 23 of Set 13 | sisimiut
# Processing Record 24 of Set 13 | the valley
# Processing Record 25 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 26 of Set 13 | haputale
# Processing Record 27 of Set 13 | ushtobe
# Processing Record 28 of Set 13 | letlhakane
# Processing Record 29 of Set 13 | umm kaddadah
# Processing Record 30 of Set 13 | presidencia roque saenz pena
# Processing Record 31 of Set 13 | yarmouth
# Processing Record 32 of Set 13 | angoram
# Processing Record 33 of Set 13 | kovylkino
# Processing Record 34 of Set 13 | tayga
# Processing Record 35 of Set 13 | ojinaga
# Processing Record 36 of Set 13 | camopi
# Processing Record 37 of Set 13 | cheuskiny
# City not found. Skipping...
# Processing Record 38 of Set 13 | sept-iles
# Processing Record 39 of Set 13 | turangi
# Processing Record 40 of Set 13 | sorong
# Processing Record 41 of Set 13 | deputatskiy
# Processing Record 42 of Set 13 | riyadh
# Processing Record 43 of Set 13 | margate
# Processing Record 44 of Set 13 | bereda
# Processing Record 45 of Set 13 | luziania
# Processing Record 46 of Set 13 | agua prieta
# Processing Record 47 of Set 13 | wang noi
# Processing Record 48 of Set 13 | gay
# Processing Record 49 of Set 13 | ekibastuz
# Processing Record 50 of Set 13 | vestmanna
# Processing Record 1 of Set 14 | havelock
# Processing Record 2 of Set 14 | freeport
# Processing Record 3 of Set 14 | houma
# Processing Record 4 of Set 14 | byron bay
# Processing Record 5 of Set 14 | butka
# Processing Record 6 of Set 14 | kawalu
# Processing Record 7 of Set 14 | saint anthony
# Processing Record 8 of Set 14 | gazanjyk
# Processing Record 9 of Set 14 | daitari
# Processing Record 10 of Set 14 | paciran
# Processing Record 11 of Set 14 | teguise
# Processing Record 12 of Set 14 | okha
# Processing Record 13 of Set 14 | gao
# Processing Record 14 of Set 14 | makat
# Processing Record 15 of Set 14 | aykhal
# Processing Record 16 of Set 14 | hoima
# Processing Record 17 of Set 14 | dauphin
# Processing Record 18 of Set 14 | boa vista
# Processing Record 19 of Set 14 | discovery bay
# Processing Record 20 of Set 14 | pitogo
# Processing Record 21 of Set 14 | mananjary
# Processing Record 22 of Set 14 | mehamn
# Processing Record 23 of Set 14 | delhi
# Processing Record 24 of Set 14 | qurayyat
# Processing Record 25 of Set 14 | ust-tsilma
# Processing Record 26 of Set 14 | telimele
# Processing Record 27 of Set 14 | kudahuvadhoo
# Processing Record 28 of Set 14 | vieste
# Processing Record 29 of Set 14 | hillsborough
# Processing Record 30 of Set 14 | quang ngai
# Processing Record 31 of Set 14 | salto
# Processing Record 32 of Set 14 | ponta delgada
# Processing Record 33 of Set 14 | batticaloa
# Processing Record 34 of Set 14 | vao
# Processing Record 35 of Set 14 | eregli
# Processing Record 36 of Set 14 | peleduy
# Processing Record 37 of Set 14 | fukue
# Processing Record 38 of Set 14 | biloela
# Processing Record 39 of Set 14 | ozernovskiy
# Processing Record 40 of Set 14 | inirida
# Processing Record 41 of Set 14 | cayhagan
# Processing Record 42 of Set 14 | pangkalanbuun
# Processing Record 43 of Set 14 | dodola
# Processing Record 44 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 14 | basco
# Processing Record 46 of Set 14 | ugento
# Processing Record 47 of Set 14 | sangar
# Processing Record 48 of Set 14 | kautokeino
# Processing Record 49 of Set 14 | soyo
# Processing Record 50 of Set 14 | belaya gora
# Processing Record 1 of Set 15 | karawang
# Processing Record 2 of Set 15 | zhongshu
# Processing Record 3 of Set 15 | cap malheureux
# Processing Record 4 of Set 15 | panshi
# Processing Record 5 of Set 15 | amazar
# Processing Record 6 of Set 15 | saint-georges
# Processing Record 7 of Set 15 | chara
# Processing Record 8 of Set 15 | shurugwi
# Processing Record 9 of Set 15 | lamesa
# Processing Record 10 of Set 15 | palu
# Processing Record 11 of Set 15 | aksarka
# Processing Record 12 of Set 15 | umea
# Processing Record 13 of Set 15 | jimma
# Processing Record 14 of Set 15 | tarauaca
# Processing Record 15 of Set 15 | new richmond
# Processing Record 16 of Set 15 | shaunavon
# Processing Record 17 of Set 15 | gulfport
# Processing Record 18 of Set 15 | petropavlovskaya
# Processing Record 19 of Set 15 | ejido
# Processing Record 20 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 15 | warragul
# Processing Record 22 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 23 of Set 15 | bogande
# Processing Record 24 of Set 15 | parana
# Processing Record 25 of Set 15 | marawi
# Processing Record 26 of Set 15 | resistencia
# Processing Record 27 of Set 15 | bubaque
# Processing Record 28 of Set 15 | siguiri
# Processing Record 29 of Set 15 | nantucket
# Processing Record 30 of Set 15 | angad
# Processing Record 31 of Set 15 | rzhyshchiv
# Processing Record 32 of Set 15 | dwarka
# Processing Record 33 of Set 15 | suntar
# Processing Record 34 of Set 15 | catuday
# Processing Record 35 of Set 15 | burgeo
# Processing Record 36 of Set 15 | rafaela
# Processing Record 37 of Set 15 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 38 of Set 15 | tocopilla
# Processing Record 39 of Set 15 | dire
# Processing Record 40 of Set 15 | dhidhdhoo
# Processing Record 41 of Set 15 | bikin
# Processing Record 42 of Set 15 | carlisle
# Processing Record 43 of Set 15 | gusau
# Processing Record 44 of Set 15 | toktogul
# Processing Record 45 of Set 15 | punakha
# Processing Record 46 of Set 15 | ourossogui
# Processing Record 47 of Set 15 | san policarpo
# Processing Record 48 of Set 15 | cam ranh
# Processing Record 49 of Set 15 | milagres
# Processing Record 50 of Set 15 | aktau
# Processing Record 1 of Set 16 | karpogory
# Processing Record 2 of Set 16 | tiarei
# Processing Record 3 of Set 16 | homer
# Processing Record 4 of Set 16 | praia da vitoria
# Processing Record 5 of Set 16 | qujing
# Processing Record 6 of Set 16 | grajau
# Processing Record 7 of Set 16 | aitape
# Processing Record 8 of Set 16 | xai-xai
# Processing Record 9 of Set 16 | dungarvan
# Processing Record 10 of Set 16 | tarko-sale
# Processing Record 11 of Set 16 | sur
# Processing Record 12 of Set 16 | teguldet
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 700

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Asau      RO  46.4333   26.4000     51.28        80          88
# 1   Tuktoyaktuk      CA  69.4541 -133.0374     24.80        93          75
# 2       Qaanaaq      GL  77.4840  -69.3632     -0.54        69           0
# 3        Rawson      AR -43.3002  -65.1023     77.86        28          50
# 4  Batemans Bay      AU -35.7167  150.1833     60.10        87         100
# 5         Vaini      TO -21.2000 -175.2000     78.96        78          75
# 6      Waingapu      ID  -9.6567  120.2641     80.10        81         100
# 7         Kapaa      US  22.0752 -159.3190     73.09        91         100
# 8          Ruwi      OM  23.5996   58.5507     78.49        34          63
# 9         Albac      RO  46.4500   22.9667     47.01        90          46
#
#    Wind Speed Current Description
# 0        1.12          light rain
# 1        4.61       broken clouds
# 2        8.77           clear sky
# 3        7.23    scattered clouds
# 4        2.53     overcast clouds
# 5        8.05       broken clouds
# 6        1.77     overcast clouds
# 7       19.57       moderate rain
# 8        2.64       broken clouds
# 9        3.58    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# Recreate the DataFrame by using the new column order

#Note: I have already set the columns in the correct order in a previous step

# %%
# Display sample data
city_data_df.sample(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 596           Butka      RU  56.7179   63.7866     40.10        86
# 684   San Policarpo      PH  12.1791  125.5072     78.39        88
# 185       Quelimane      MZ -17.8786   36.8883     76.95        83
# 593        Freeport      US  40.6576  -73.5832     55.26        47
# 1       Tuktoyaktuk      CA  69.4541 -133.0374     24.80        93
# 669      Rzhyshchiv      UA  49.9689   31.0463     48.94        78
# 113         Kavieng      PG  -2.5744  150.7967     82.63        76
# 34   Saint-Augustin      CA  51.2260  -58.6502     54.19        76
# 690           Homer      US  59.6425 -151.5483     44.49        73
# 170         Waipawa      NZ -41.4122  175.5153     55.49        56
#
#      Cloudiness  Wind Speed Current Description
# 596          98        8.48     overcast clouds
# 684          98        4.70       moderate rain
# 185          40        4.61    scattered clouds
# 593          40       18.41    scattered clouds
# 1            75        4.61       broken clouds
# 669          98       11.54          light rain
# 113          99       12.03     overcast clouds
# 34           93        9.22     overcast clouds
# 690          75       15.99       broken clouds
# 170           4        4.97           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
